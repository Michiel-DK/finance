# %%
from finance.mongo.insertion import get_all_tickers, api_key_metrics

# %%
get_all_tickers('finance', 'all_tickers')

# %%
from finance.params import *

# %%
client = PY_MONGO_CLIENT
collection = client['finance']['all_tickers']

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True), 'finance'), 'all_tickers')

# %%
big_ls = list(collection.find({'type':'stock'}))

# %%
big_ls[:10]
# Out:
# [{'_id': ObjectId('6579cc66a066b246a01b8f0b'),
#   'symbol': 'TGNA',
#   'name': 'TEGNA Inc.',
#   'price': 14.875,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0c'),
#   'symbol': 'M',
#   'name': "Macy's, Inc.",
#   'price': 18.8599,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0d'),
#   'symbol': 'SB',
#   'name': 'Safe Bulkers, Inc.',
#   'price': 3.715,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0e'),
#   'symbol': 'PACB',
#   'name': 'Pacific Biosciences of California, Inc.',
#   'price': 8.18,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0f'),
#   'symbol': 'LXFR',
#   'name': 'Luxfer Holdings PLC',
#   'price': 8.92,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f10'),
#   'symbol': 'TOST',
#   'name': 'Toast, Inc.',
#   'price': 15.3125,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f11'),
#   'symbol': 'ENVX',
#   'name': 'Enovix Corporation',
#   'price': 11.7479,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f12'),
#   'symbol': 'TS',
#   'name': 'Tenaris S.A.',
#   'price': 32.96,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f13'),
#   'symbol': 'SLP',
#   'name': 'Simulations Plus, Inc.',
#   'price': 39.42,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f14'),
#   'symbol': 'CL',
#   'name': 'Colgate-Palmolive Company',
#   'price': 78.775,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'}]

# %%
api_key_metrics(big_ls[310+74:], 'finance', 'key_metrics')
# Out:
# TRP.TO
# ARX.TO
# GTLB
# GRNT
# JBLU
# IR
# GRIN
# GMBL
# ELAN
# CTRA
# APLD
# STN.TO
# TTE
# EL
# SM
# NDAQ
# HBAN
# CAE
# SOFI
# HAL
# ALNY
# MOND
# PKX
# SWN
# TWO
# AMAT
# GATO
# ET
# RXRX
# U
# JNJ
# RNST
# STAA
# FSLY
# APA
# DHR
# USWE.ST
# YUM
# NVCR
# WEC
# MS
# PLUG
# AAP
# HES
# NVA.TO
# GBTG
# UPS
# MBLY
# EPI-A.ST
# COST
# FCX
# ADCT
# CTLT
# GM
# PANW
# C
# PCG
# ALGT
# ROKU
# WAL
# VRDN
# ACRS
# SAVE
# SRE
# SES
# GREEN.ST
# SHEL
# CVAC
# NEO
# ABNB
# RCM
# BQ
# RES
# BRBR
# CLF
# EQNR
# CGC
# BLFS
# DOW
# BBAI
# BBIO
# CLCO
# EMN
# NU
# RBLX
# ENPH
# FANG
# FCEL
# SNOA
# CHTR
# ESTC
# SHLS
# ATRC
# ALC
# BMY
# H.TO
# HBIO
# CELH
# GETY
# KWR
# ABEV
# CMCSA
# ZION
# PKI.TO
# UA
# EAT
# BBWI
# TFC
# WERN
# YUMC
# ON
# DM
# OPEN
# SEAS
# CADL
# BRK-A
# MHO
# CJ.TO
# PRTS
# WFC
# VLO
# WCP.TO
# TMUS
# LNG
# CRK
# WES
# SHB-A.ST
# IONQ
# CAKE
# DAL
# AER
# DAKT
# GIS
# KDP
# CNQ.TO
# NXTP
# NRG
# EBS
# VLN
# CPRT
# SSAB-A.ST
# PSX
# NPI.TO
# VERX
# HA
# GOOG
# CVE.TO
# NVS
# CG
# ES
# SFNC
# SAP
# VC
# AMKR
# BEDU
# MTTR
# IVZ
# PGNY
# LSXMK
# TNDM
# XOM
# LIFE
# SKIN
# MPW
# ZETA
# NOC
# FSR
# AES
# DFH
# NWL
# DUK
# UTF
# EMR
# FTI
# OBE.TO
# VAPO
# HCAT
# COF
# DCO
# OKE
# CCL-B.TO
# CVE
# RGEN
# NRDY
# DKNG
# EOG
# PGR
# HLF
# NFLX
# CHWY
# PAGS
# FUTU
# GRCL
# SPWR
# BRAV.ST
# SSAB-B.ST
# SRPT
# PYXS
# VERV
# ALKS
# WYNN
# STVN
# TEAM
# MCHP
# SU.TO
# EOSE
# AMGN
# AEP
# FIS
# Z
# FTAI
# PETQ
# ZAPP
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 api_key_metrics(big_ls[310+74:], 'finance', 'key_metrics')
#
# File ~/code/Michiel-DK/finance/finance/mongo/insertion.py:80, in api_key_metrics(tickers, database, table)
#      76 print(symbol)
#      78 response = key_metrics(symbol, period='quarter')
# ---> 80 insert_tabular(response)
#
# File ~/code/Michiel-DK/finance/finance/mongo/insertion.py:68, in api_key_metrics.<locals>.insert_tabular(ls)
#      64 client = PY_MONGO_CLIENT
#      66 collection = client[database][table]
# ---> 68 collection.insert_many(ls)
#      70 return None
#
# File ~/.pyenv/versions/3.10.6/envs/finance/lib/python3.10/site-packages/pymongo/_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/envs/finance/lib/python3.10/site-packages/pymongo/collection.py:739, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     690 """Insert an iterable of documents.
#     691
#     692   >>> db.test.count_documents({})
#    (...)
#     732 .. versionadded:: 3.0
#     733 """
#     734 if (
#     735     not isinstance(documents, abc.Iterable)
#     736     or isinstance(documents, abc.Mapping)
#     737     or not documents
#     738 ):
# --> 739     raise TypeError("documents must be a non-empty list")
#     740 inserted_ids: list[ObjectId] = []
#     742 def gen() -> Iterator[tuple[int, Mapping[str, Any]]]:
#
# TypeError: documents must be a non-empty list
