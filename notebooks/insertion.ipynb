# %%
from finance.mongo.insertion import get_all_tickers, api_key_metrics

# %%
get_all_tickers('finance', 'all_tickers')

# %%
from finance.params import *

# %%
client = PY_MONGO_CLIENT
collection = client['finance']['all_tickers']

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27018'], document_class=dict, tz_aware=False, connect=True), 'finance'), 'all_tickers')

# %%
big_ls = list(collection.find({'type':'stock'}))

# %%
big_ls[:10]
# Out:
# [{'_id': ObjectId('6579cc66a066b246a01b8f0b'),
#   'symbol': 'TGNA',
#   'name': 'TEGNA Inc.',
#   'price': 14.875,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0c'),
#   'symbol': 'M',
#   'name': "Macy's, Inc.",
#   'price': 18.8599,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0d'),
#   'symbol': 'SB',
#   'name': 'Safe Bulkers, Inc.',
#   'price': 3.715,
#   'exchange': 'New York Stock Exchange',
#   'exchangeShortName': 'NYSE',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0e'),
#   'symbol': 'PACB',
#   'name': 'Pacific Biosciences of California, Inc.',
#   'price': 8.18,
#   'exchange': 'NASDAQ Global Select',
#   'exchangeShortName': 'NASDAQ',
#   'type': 'stock'},
#  {'_id': ObjectId('6579cc66a066b246a01b8f0f'),
#   'symbol': 'LXFR',
# ...

# %%
api_key_metrics(big_ls[310+74+213+38298:], 'finance', 'key_metrics')
# Out:
# 2663.HK
# 0210.HK
# 1446.HK
# 2182.HK
# 3398.HK
# 0720.HK
# 0571.HK
# 8296.HK
# 8423.HK
# 8611.HK
# 8668.HK
# 8098.HK
# 0193.HK
# RICO.L
# 002989.SZ
# 0599.HK
# 2821.HK
# 0265.HK
# 0333.HK
# 3666.HK
# 4018.F
# 1262.HK
# 1701.HK
# 1402.HK
# 9929.HK
# ---- error for {'_id': ObjectId('6579cc66a066b246a01c5dc0'), 'symbol': '9929.HK', 'name': 'SEM Holdings Limited', 'price': 0.042, 'exchange': 'HKSE', 'exchangeShortName': 'HKSE', 'type': 'stock'} ----
# 1580.HK
# 2320.HK
# 1305.HK
# 1148.HK
# 1058.HK
# 1960.HK
# 0674.HK
# 2682.HK
# 7446.T
# 8366.HK
# 1290.HK
# 1163.HK
# 2176.HK
# 8290.HK
# 2292.HK
# 8121.HK
# 1872.HK
# 1278.HK
# 6038.HK
# 8227.HK
# CAG.AX
# LRL.AX
# MHK.AX
# ABV.AX
# IRD.AX
# ENX.AX
# EGY.AX
# NSM.AX
# 8385.HK
# 0724.HK
# 0997.HK
# 0684.HK
# LRD.AX
# ...
